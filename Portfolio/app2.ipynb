# %%
import dash
import dash_renderer
import plotly.graph_objs as go
import dash_html_components as html
import dash_core_components as dcc

import pandas as pd

# %%
# Datenvorverarbeitung
data = pd.read_csv("data_01.csv")
data_verzoegert = data[data["deviation cause"]!= 0]
data_ver_net= data_verzoegert.groupby(["deviation cause"])["Net Value"].sum() #["Net Value", "deviation indicator", "deviation cause text"]
data_ver_net
data_verzoegert
# Out:
#        Unnamed: 0 Document Date Year/Month  Year  Month  \
# 0               0    2019-02-28     2019/2  2019      2
# 1               1    2019-02-28     2019/2  2019      2
# 2               2    2019-02-28     2019/2  2019      2
# 3               3    2019-02-28     2019/2  2019      2
# 4               4    2019-02-28     2019/2  2019      2
# ...           ...           ...        ...   ...    ...
# 12028       12028    2020-01-04     2020/1  2020      1
# 12036       12036    2020-01-21     2020/1  2020      1
# 12037       12037    2020-01-21     2020/1  2020      1
# 12044       12044    2020-02-01     2020/2  2020      2
# 12045       12045    2020-02-01     2020/2  2020      2
#
#       supplier delivery date delivery date  Company Code Country  \
# 0                 2019-03-07    2019-03-07            52      AT
# 1                 2019-03-07    2019-03-07            52      AT
# 2                 2019-03-07    2019-03-07            52      AT
# 3                 2019-03-07    2019-03-07            52      AT
# 4                 2019-03-07    2019-03-07            52      AT
# ...                      ...           ...           ...     ...
# 12028             2020-01-11    2020-01-15            53      GB
# 12036             2020-01-28    2020-02-01            53      GB
# 12037             2020-01-28    2020-02-01            53      GB
# 12044             2020-02-08    2020-02-12            53      GB
# 12045             2020-02-08    2020-02-12            53      GB
#
#        Purchasing Doc.  ...  ORDERED Quantity  Delivered QTY  open quantity  \
# 0           8207406178  ...              10.0            7.0              3
# 1           8207406178  ...              10.0            7.0              3
# 2           8207406178  ...              10.0            7.0              3
# 3           8207406178  ...              10.0            7.0              3
# 4           8207406178  ...              13.0           10.0              3
# ...                ...  ...               ...            ...            ...
# 12028       8207890736  ...               8.0            8.0              0
# 12036       8207914670  ...               6.0            6.0              0
# 12037       8207914671  ...               4.0            4.0              0
# 12044       8207935452  ...               8.0            8.0              0
# 12045       8207935454  ...               4.0            4.0              0
#
#        deviation indicator deviation cause           deviation cause text  \
# 0                  in time               3                 under-delivery
# 1                  in time               3                 under-delivery
# 2                  in time               3                 under-delivery
# 3                  in time               3                 under-delivery
# 4                  in time               3                 under-delivery
# ...                    ...             ...                            ...
# 12028       late: < 5 days               7  delivery deviation - too late
# 12036       late: < 5 days               7  delivery deviation - too late
# 12037       late: < 5 days               7  delivery deviation - too late
# 12044       late: < 5 days               7  delivery deviation - too late
# 12045       late: < 5 days               7  delivery deviation - too late
#
#       Net Value Local Currency Counter  Delivery deviation in days
# 0       6720.00            EUR       1                         0.0
# 1      18162.00            EUR       1                         0.0
# 2       5710.00            EUR       1                         0.0
# 3      29890.00            EUR       1                         0.0
# 4       9646.00            EUR       1                         0.0
# ...         ...            ...     ...                         ...
# 12028  10165.44            EUR       1                         4.0
# 12036   3479.52            EUR       1                         4.0
# 12037   5297.32            EUR       1                         4.0
# 12044  10165.44            EUR       1                         4.0
# 12045   5297.32            EUR       1                         4.0
#
# [232 rows x 35 columns]

# %%
data_verzoegert_weiter = data_verzoegert 
data_verzoegert = data_verzoegert.drop_duplicates(subset = "Purchasing Doc.") # etwas unsauber aber funktioniert um nur die Anzahl an Bestellungen zu bekommen
temp = sorted(data_verzoegert["deviation cause"].unique())
x = {}
for i in temp:
    x.update({int(i):len(data_verzoegert[data_verzoegert["deviation cause"]==i])}) # muss noch angepasst werden auf unique Bestellungen

x.values()
# Out:
# dict_values([13, 3, 30, 1, 9, 99, 3, 1, 6])

# %%
data3 = data_ver_net.to_frame()
data3.loc[:,"anzahl"] = x.values()#.loc[:,'numbers of deviation'] = x.values()

# %%
data3.index
# Ende der Datenvorbereitung für ersten Graph bei 2.3
# Out:
# Int64Index([1, 2, 3, 4, 5, 7, 8, 9, 10], dtype='int64', name='deviation cause')

# %% [markdown]
# # Datenvorbereitung zweiter Graph 2.3.2
# ## soll Höhe der Verzögerung darstellen bei den zu spät Lieferungen erstmal als scatterplot

# %%
data_verzoegert_weiter = data_verzoegert_weiter[data_verzoegert_weiter['deviation cause']==7].drop_duplicates(subset="Purchasing Doc.") # Annahme: Lieferung kommt immer zusammen
data_3_2_1 = data_verzoegert_weiter.groupby("deviation indicator").count()
data_3_2_2 = data_verzoegert_weiter.groupby("deviation indicator")["Net Value"].sum()
data_3_2_1.iloc[:,0].to_frame()
# Out:
#                      Unnamed: 0
# deviation indicator
# late: 5 to 10 days           35
# late: < 5 days               59
# late: > 10 days               5

# %%
app = dash.Dash()

# %%
colors = { # Farben können an den Styleguide angepasst werden und werden für alle Diagramme übernommen
    'text1' : '#ff0000', # Farbe für normale Schrift
    'text2' : '#0B610B', # Variation der Schriftfarbe
    # Farbe für Hintergründe des Plots
    'plot_bgcolor' : '#000000', # um papercolor herum außerhalb des plots
    'paper_bgcolor' : '#888888',# Farbe für Hintergründe des Paperbackground (vor plot background)
    'color_text_in_plots': '#ffffff' # Farbe für die Texte im Plot
}

# %% [markdown]
# Dashboard Seite 2 Aufgabe 3:
#     Gesamtsumme Ordered Spend & Anzahl Bestellungen der abweichenden
#     Lieferungen nach Abweichungsgründen (deviation cause) & Höhe der
#     Verzögerung (deviation indicator)

# %%
app.layout = html.Div([
    html.H1(children = 'Lieferanten',
            style = {
                'textAlign' : 'center',
                'color' : colors['text1']
            }
    
    
    ),
    html.Div(children = 'Dashboard for suppliers',
            style = {
                'textAlign' : 'center',
                'color' : colors['text1']
            }),

    dcc.Graph( # bar chart aus Aufgabe 2 Stichpunkt 3
        id = "bar3",
        figure = 
        {
            'data': 
            [
                {
                    'x': data3.index,
                    'y': data3["Net Value"],
                    'type': 'bar',
                    'name': 'deviation causes and deviation indicator'
                },
                {
                    'x': data3.index,
                    'y': data3["anzahl"],
                    'type': 'bar',
                    'name': 'deviation causes and deviation indicator'
                }
                # funktionert aber um es schöner in einem Diagramm zu machen zwei y-Achsen (links und rechts) verwenden
                # Skalierung schlecht
            ],
            # brauchen noch einen Styleguide für Fabren etc.
            'layout' :
            {   
                'plot_bgcolor' : colors['plot_bgcolor'], # um papercolor herum außerhalb des plots
                'paper_bgcolor' : colors['paper_bgcolor'], # das was direkt um den plot rum isst als Hintergrund
                'font': {
                    'color': colors['color_text_in_plots'],
                    'fontsize': '15px'
                },
                'title':'Ordered spend and numbers of dissenting orders according to deviation causes'
            }

        }
    ),
    dcc.Graph(
        id = "scatter3",
        figure= {
            'data':
            [
                
            ]




        }

    )


])

# %%
if __name__ =='__main__':
    app.run_server(port=8050)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [16/Aug/2021 11:58:20] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:58:20] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:58:20] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:58:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:58:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:58:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:58:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:58:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:58:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:58:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:58:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:58:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:58:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:58:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:58:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:58:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 11:59:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:00:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:03] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:06] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:09] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:12] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:15] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:18] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:21] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:24] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:27] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:30] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:33] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:36] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:39] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:42] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:45] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:48] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:51] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:54] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:01:57] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:02:00] "GET /_reload-hash HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2021 12:02:03] "GET /_reload-hash HTTP/1.1" 200 -
